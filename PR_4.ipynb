# %%
import pandas as pd

# %%
laptops_df =pd.read_csv('laptops.csv')
laptops_df
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# ...

# %%
laptops_df.head()#값을 안 넣으면 디폴트값은 5개임 그리고 원하는개수 출력가능
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# ...

# %%
laptops_df.head(7)
# Out:
#    brand                   model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell        Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple             MacBook Air    8     ssd      128         13.3   55499
# 2  Apple             MacBook Air    8     ssd      256         13.3   71500
# 3  Apple             MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple             MacBook Pro    8     ssd      256         13.3  112666
# 5  Apple  MacBook Pro (TouchBar)   16     ssd      512         15.0  226000
# 6  Apple  MacBook Pro (TouchBar)   16     ssd      512         13.3  158000
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# ...

# %%
laptops_df.tail()#뒤에서 5개 출력함 default는 5이므로
# Out:
#     brand           model  ram hd_type  hd_size  screen_size  price  \
# 162  Asus          A555LF    8     hdd     1024         15.6  39961
# 163  Asus   X555LA-XX172D    4     hdd      500         15.6  28489
# 164  Asus          X554LD    2     hdd      500         15.6  29199
# 165  Asus  X550LAV-XX771D    2     hdd      500         15.6  29990
# 166  Asus   X540LA-XX538T    4     hdd     1024         15.6  30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# 162           intel      i3 4th gen          1.7             nvidia
# 163           intel      i3 4th gen          1.9              intel
# 164           intel      i3 4th gen          1.9              intel
# 165           intel      i3 4th gen          1.7              intel
# 166           intel      i3 5th gen          2.0              intel
#
#      graphic_card_size       os  weight comments
# 162                2.0  windows     2.3      NaN
# ...

# %%
laptops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               167 non-null    object
#  1   model               167 non-null    object
#  2   ram                 167 non-null    int64
#  3   hd_type             167 non-null    object
#  4   hd_size             167 non-null    int64
#  5   screen_size         167 non-null    float64
#  6   price               167 non-null    int64
#  7   processor_brand     167 non-null    object
#  8   processor_model     167 non-null    object
#  9   clock_speed         166 non-null    float64
#  10  graphic_card_brand  163 non-null    object
#  11  graphic_card_size   81 non-null     float64
#  12  os                  167 non-null    object
#  13  weight              160 non-null    float64
#  14  comments            55 non-null     object
# ...

# %%
laptops_df.sort_values(by='price')#price별로 보여줌 오름차순
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# ..         ...                         ...  ...     ...      ...          ...
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
#
# ...

# %%
laptops_df.sort_values(by='price',ascending =False)
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ..         ...                         ...  ...     ...      ...          ...
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
#
# ...

# %%
laptops_df['brand']
# Out:
# 0       Dell
# 1      Apple
# 2      Apple
# 3      Apple
# 4      Apple
#        ...
# 162     Asus
# 163     Asus
# 164     Asus
# 165     Asus
# 166     Asus
# Name: brand, Length: 167, dtype: object

# %%
laptops_df['brand'].unique()#set()이랑 비슷함
# Out:
# array(['Dell', 'Apple', 'Acer', 'HP', 'Lenovo', 'Alienware', 'Microsoft',
#        'Asus'], dtype=object)

# %%
laptops_df['brand'].value_counts()#브랜드 별로 개수 세어줌
# Out:
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Alienware     6
# Microsoft     6
# Name: brand, dtype: int64

# %%
laptops_df['brand'].describe()
# Out:
# count     167
# unique      8
# top        HP
# freq       55
# Name: brand, dtype: object

# %% [markdown]
# # 여행

# %%
df = pd.read_csv('world_cities.csv')
df
# Out:
#      Unnamed: 0 City / Urban area     Country  Population  Land area (in sqKm)
# 0             0      Buenos Aires   Argentina    11200000                 2266
# 1             1         Melbourne   Australia     3162000                 2080
# 2             2            Sydney   Australia     3502000                 1687
# 3             3          Brisbane   Australia     1508000                 1603
# 4             4             Perth   Australia     1177000                  964
# ..          ...               ...         ...         ...                  ...
# 244         245            Canton         USA      267000                  372
# 245         246           Spokane         USA      335000                  371
# 246         247          Tashkent  Uzbekistan     2200000                  531
# 247         248  Ho Chi Minh City     Vietnam     4900000                  518
# 248         249            Harare    Zimbabwe     1750000                  712
#
# [249 rows x 5 columns]

# %%
df.describe()#seaborn이 더 좋음
# Out:
#        Unnamed: 0    Population  Land area (in sqKm)
# count  249.000000  2.490000e+02           249.000000
# mean   124.273092  3.006538e+06          1035.212851
# std     72.369388  4.136435e+06          1033.487331
# min      0.000000  1.810000e+05           365.000000
# 25%     62.000000  5.980000e+05           511.000000
# 50%    124.000000  1.500000e+06           684.000000
# 75%    187.000000  3.502000e+06          1116.000000
# max    249.000000  3.320000e+07          8683.000000

# %% [markdown]
# # df에서 조건문 하는 방법

# %%
a=[False]*200 +[True]*49

# %%
df[a]
# Out:
#      Unnamed: 0        City / Urban area     Country  Population  \
# 200         201              Baton Rouge         USA      479000
# 201         202      Sarasota//Bradenton         USA      559000
# 202         203                 Columbia         USA      421000
# 203         204             Poughkeepsie         USA      352000
# 204         205                    Tulsa         USA      558000
# 205         206                 San Jose         USA     1538000
# 206         207             Grand Rapids         USA      539000
# 207         208            Winston/Salem         USA      299000
# 208         209                Worcester         USA      430000
# 209         210                  Augusta         USA      336000
# 210         211                    Flint         USA      365000
# 211         212               Charleston         USA      423000
# 212         213           Salt Lake City         USA      888000
# ...

# %%
df[df["Country"]=="USA"]
# Out:
#      Unnamed: 0        City / Urban area Country  Population  \
# 141         141           New York Metro     USA    17800000
# 142         142                  Chicago     USA     8308000
# 143         143                  Atlanta     USA     3500000
# 144         144             Philadelphia     USA     5149000
# 145         145                   Boston     USA     4032000
# ..          ...                      ...     ...         ...
# 241         242               Shreveport     USA      275000
# 242         243                 Honolulu     USA      718000
# 243         244  Bonita Springs / Naples     USA      221000
# 244         245                   Canton     USA      267000
# 245         246                  Spokane     USA      335000
#
#      Land area (in sqKm)
# 141                 8683
# 142                 5498
# 143                 5083
# 144                 4661
# 145                 4497
# ..                   ...
# 241                  401
# ...

# %% [markdown]
# # 문제
# 인구밀도 인구 수/땅의 면적
#
# 10000 이상

# %%
df["Population"] / df ["Land area (in sqKm)"] >= 10000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# Length: 249, dtype: bool

# %%
df[(df["Population"] / df ["Land area (in sqKm)"] >= 10000)]
# Out:
#      Unnamed: 0 City / Urban area      Country  Population  \
# 32           32           Beijing        China     8614000
# 33           33          Shanghai        China    10000000
# 34           34          Shenzhen        China     8000000
# 36           36           Tianjin        China     4750000
# 38           38            Bogota     Colombia     7000000
# 39           39          Kinshasa        Congo     5000000
# 71           71             Delhi        India    14300000
# 73           73         Bangalore        India     5400000
# 74           74           Kolkata        India    12700000
# 75           75            Mumbai        India    14350000
# 76           76           Chennai        India     5950000
# 77           77           Jakarta    Indonesia    14250000
# 78           78            Tehran         Iran     7250000
# 99           99             Lagos      Nigeria    13400000
# 101         101           Karachi     Pakistan     9800000
# ...

# %%
df['rate']=df["Population"] / df ["Land area (in sqKm)"]

# %%
df[(df["Population"] / df ["Land area (in sqKm)"] >= 10000)]
# Out:
#      Unnamed: 0 City / Urban area      Country  Population  \
# 32           32           Beijing        China     8614000
# 33           33          Shanghai        China    10000000
# 34           34          Shenzhen        China     8000000
# 36           36           Tianjin        China     4750000
# 38           38            Bogota     Colombia     7000000
# 39           39          Kinshasa        Congo     5000000
# 71           71             Delhi        India    14300000
# 73           73         Bangalore        India     5400000
# 74           74           Kolkata        India    12700000
# 75           75            Mumbai        India    14350000
# 76           76           Chennai        India     5950000
# 77           77           Jakarta    Indonesia    14250000
# 78           78            Tehran         Iran     7250000
# 99           99             Lagos      Nigeria    13400000
# 101         101           Karachi     Pakistan     9800000
# ...

# %% [markdown]
# # 데이터 변형, 슬라이싱

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv("iphone.csv",index_col=0) # 추가 옵션으로 index_col=0이라고하면 인덱스가 0인게 제일 먼저 나옴
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 7','메모리']
# Out:
# '2GB'

# %%
iphone_df.loc['iPhone 7',:]
# Out:
# 출시일        2016-09-16
# 디스플레이             4.7
# 메모리               2GB
# 출시 버전        iOS 10.0
# Face ID            No
# Name: iPhone 7, dtype: object

# %% [markdown]
# # iphone_df['rate']==df.loc[:,'rate'] 같은 의미이다.

# %%
iphone_df['출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df.loc[:,'출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df.loc['iPhone 7',:]==iphone_df.loc['iPhone 7']
# Out:
# 출시일        True
# 디스플레이      True
# 메모리        True
# 출시 버전      True
# Face ID    True
# Name: iPhone 7, dtype: bool

# %%
#iphone_df.loc['iPhone 7','iPhone 8']# 이렇게 하면 안됨.
iphone_df.loc[['iPhone 7','iPhone 8']]#단일 데이터가 아니라면 리스트 형식으로 넣어줘야한다.
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No

# %%
iphone_df.loc['iPhone 7': 'iPhone X']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes

# %% [markdown]
# ## 데이터 변형하기
# ##### 원본데이터 망가질 수 있음

# %%
iphone_df.loc['iPhone 7','메모리']='1TB'
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  1TB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['디스플레이']=10

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     10  1TB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16     10  3GB  iOS 10.0      No
# iPhone 8       2017-09-22     10  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22     10  3GB  iOS 11.0      No
# iPhone X       2017-11-03     10  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21     10  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21     10  4GB  iOS 12.0     Yes

# %% [markdown]
# ##### 위에는 조건문을 통해서도 가능함

# %% [markdown]
# ##### 삭제

# %%
iphone_df.drop('출시일',axis='index')#inplace =true하면 원본에도 적용
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-acb1fc0d550f> in <module>
# ----> 1 iphone_df.drop('출시일')#inplace =true하면 원본에도 적용
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     10  1TB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16     10  3GB  iOS 10.0      No
# iPhone 8       2017-09-22     10  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22     10  3GB  iOS 11.0      No
# iPhone X       2017-11-03     10  3GB  iOS 11.1     Yes
# iPhone XS Max  2018-09-21     10  4GB  iOS 12.0     Yes
